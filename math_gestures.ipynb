# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashBhardwaj9078/Demo_git_work/blob/main/math_gestures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import cv2
# import numpy as np
# import time
# import mediapipe as mp

# cap=cv2.VideoCapture(0)
# cap.set(3,640)
# cap.set(4,480)

# while True:
#   ret,frame=cap.read()
#   frame=cv2.flip(frame,1)
#   if not ret:
#     break
#   cv2.imshow('frame',frame)
#   if cv2.waitKey(1) & 0xFF==ord('q'):
#     break

# cap.release()
# cv2.destroyAllWindows()
import cv2
import numpy as np
import time
import mediapipe as mp
from PIL import Image

import google.generativeai as genai
import os
key="AIzaSyARAzgDZVTtpxQ5HpAtbsBdM5tm3-R7Bxg"

genai.configure(api_key=key)
model = genai.GenerativeModel('gemini-1.5-flash')

cap=cv2.VideoCapture(0)
cap.set(3,640)
cap.set(4,480)

prev_pos=None
canvas=None



import PIL

import streamlit as st

st.set_page_config(layout="wide")
st.image('MathGestures-1536x144.png')

col1,col2=st.columns([2,1])

with col1:
  run=st.checkbox("run",value=True)
  frame_window=st.image([])

with col2:
  output_title=st.title("Answer")
  output_text=st.subheader("")




def sendToAi(model,canvas,fingers):
  if fingers==[0,1,1,1,0]:
    canvas=Image.fromarray(canvas)
    response = model.generate_content(["solve this math problem",canvas])
    return (response.text)


def draw(lmlist,fingers,prev_pos,frame):
  x,y=lmlist[8]
#   bind your thumb , it will be counted as open due to the image being flipped and use your open index finger to draw and in
#   order to halt open up your middle fingure
  if fingers==[1,1,0,0,0]:
    if prev_pos is None:
      prev_pos=(x,y)
    cv2.line(frame,(x,y),prev_pos,(255,0,0),8)







  return (x,y),canvas

hands=mp.solutions.hands.Hands()
mp_draw=mp.solutions.drawing_utils
ptime=0


while True:
  ret,frame=cap.read()
  frame=cv2.flip(frame,1)
  frm_rgb=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
  results=hands.process(frm_rgb)


  if results.multi_hand_landmarks:
    for handLms in results.multi_hand_landmarks:
      mp_draw.draw_landmarks(frame,handLms,mp.solutions.hands.HAND_CONNECTIONS)
    #   landmarks = handLms.landmark
    #   x_min = min(landmarks[:, 0])
    #   x_max = max(landmarks[:, 0])
    #   y_min = min(landmarks[:, 1])
    #   y_max = max(landmarks[:, 1])
    #   cv2.rectangle(frame,(x_min-10,y_min-10),(x_max+10,y_max+10),(0,255,0),3)
















      fh,fw,fc=frame.shape
      lmlist=dict([(id,[int(lm.x*fw),int(lm.y*fh)]) for id,lm in enumerate(handLms.landmark)])

      if canvas is None:
          canvas=np.zeros_like(frame)










    #   tips = [4, 8, 12, 16, 20]
    #   fingers=[]
    #   for id in tips:

    #     #   thumb
    #       if id==4:
    #           if lmlist[id][0]>lmlist[id-1][0]:
    #               fingers.append(1)
    #           else:
    #               fingers.append(0)
    #       else:
    #           if lmlist[id][1]<lmlist[id-2][1]:
    #               fingers.append(1)
    #           else:
    #               fingers.append(0)

    #   print(fingers)
      tips = [4, 8, 12, 16, 20]
      fingers=[]
      for id in tips:

        #   thumb
          if id==4:
              if lmlist[id][0]>lmlist[id-1][0]:
                  fingers.append(1)
              else:
                  fingers.append(0)
          else:
              if lmlist[id][1]<lmlist[id-2][1]:
                  fingers.append(1)
              else:
                  fingers.append(0)

      print(fingers)

      x1,y1=lmlist[4]
      x2,y2=lmlist[8]
      cx,cy=(x1+x2)//2,(y1+y2)//2

      cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
      cv2.circle(frame,(x1,y1),15,(0,255,0),-1)
      cv2.circle(frame,(x2,y2),15,(0,255,0),-1)
      cv2.circle(frame,(cx,cy),15,(0,255,0),-1)
      prev_pos,canvas=draw(lmlist,fingers,prev_pos,canvas)
      ans=sendToAi(model,canvas,fingers)
      if ans:
          output_text.text(ans)











    #   cv2.rectangle(frame,(lmlist[0][1],lmlist[4][0]),(lmlist[20][0],lmlist[12][1]),(0,255,0),4)

    #   bbox=handLms.landmark.location_data.relative_bounding_box
    #   x,y,w,h=int(bbox.xmin*fw),int(bbox.ymin*fh),int(bbox.width*fw),int(bbox.height*fh)
    #   cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)





  ctime=time.time()
  fps=1/(ctime-ptime)
  ptime=ctime
  cv2.putText(frame,str(int(fps)),(10,70),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),3)

  if not ret:
    break


  if canvas is not None:
    frame=cv2.addWeighted(frame,0.7,canvas,0.3,gamma=0)
    # cv2.imshow("canvas", img_comb)
  cv2.imshow("frame",frame)
  frame_window.image(frame,channels="BGR")

  if cv2.waitKey(1) & 0xFF==ord('q'):
    break

cap.release()
cv2.destroyAllWindows()

# %%
# https://www.youtube.com/watch?v=mEsleV16qdo&t=35343s
# genai kr
